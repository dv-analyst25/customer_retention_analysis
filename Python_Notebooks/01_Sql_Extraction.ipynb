# %%
# !pip install sqlalchemy pymysql psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 847.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 847.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 847.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 847.2 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 847.2 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 436.1 kB/s eta 0:00:05
#    --------------- ------------------------ 1.0/2.7 MB 502.2 kB/s eta 0:00:04
#    --------------- ------------------------ 1.0/2.7 MB 502.2 kB/s eta 0:00:04
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine("mysql+pymysql://root:Dev0123@localhost:3306/customers_db")

# %% [markdown]
# Loading Retention View

# %%
retention = pd.read_sql("SELECT * FROM retention_base", engine)

# %%
retention.head()
# Out:
#   user_id signup_month    last_active_date  total_sessions  active_months  \
# 0  U00001      2023-02 2023-06-18 09:49:00              18              4
# 1  U00002      2023-05 2023-09-18 00:17:00              10              3
# 2  U00003      2023-03 2023-07-11 18:56:00              19              5
# 3  U00004      2023-10 2024-02-02 09:12:00              13              5
# 4  U00005      2023-08 2023-12-03 23:45:00              13              5
#
#    churned  churn_date
# 0        1  2023-05-03
# 1        0        None
# 2        0        None
# 3        1  2024-01-21
# 4        1  2023-10-08

# %% [markdown]
# Loading Sessions View

# %%
sessions = pd.read_sql("SELECT * FROM session_analytics", engine)

# %%
sessions.head()
# Out:
#   session_id user_id session_date       session_start         session_end  \
# 0   S0000001  U00001   2023-04-09 2023-04-09 17:08:00 2023-04-09 17:11:00
# 1   S0000002  U00001   2023-05-31 2023-05-31 13:24:00 2023-05-31 13:25:00
# 2   S0000003  U00001   2023-05-02 2023-05-02 03:04:00 2023-05-02 03:22:00
# 3   S0000004  U00001   2023-03-17 2023-03-17 04:30:00 2023-03-17 04:31:00
# 4   S0000005  U00001   2023-03-05 2023-03-05 18:42:00 2023-03-05 19:17:00
#
#    session_duration_minutes  pages_visited source_channel day_type
# 0                         3              1       Referral  Weekend
# 1                         1             11       Referral  Weekday
# 2                        18              7           Paid  Weekday
# 3                         1             18       Referral  Weekday
# 4                        35              2       Referral  Weekend

# %% [markdown]
# Loading Feature Usage View

# %%
features = pd.read_sql("SELECT * FROM feature_usage_summary", engine)

# %%
features.head()
# Out:
#   user_id  total_feature_events  unique_features_used top_feature_used  \
# 0  U00001                     6                     4  Advanced_Filter
# 1  U00002                     9                     5  Advanced_Filter
# 2  U00003                    10                     2         Wishlist
# 3  U00004                     2                     2  Advanced_Filter
# 4  U00005                     2                     2    Notifications
#
#    used_in_last_7_days
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# Loading churn view

# %%
churn = pd.read_sql("SELECT * FROM churn_analysis", engine)

# %%
churn.head()
# Out:
#   user_id cancel_date  cancel_reason plan_type subscription_start_date  \
# 0  U00001  2023-05-03  Too Expensive      Free              2023-02-27
# 1  U00004  2024-01-21  Too Expensive      Free              2023-10-07
# 2  U00005  2023-10-08  Too Expensive      Free              2023-08-05
# 3  U00006  2023-03-31     Not Useful      Free              2023-02-17
# 4  U00018  2023-08-28  Too Expensive      Free              2023-07-13
#
#      last_active_date  total_sessions_before_churn  feature_usage_before_churn
# 0 2023-06-18 09:49:00                           11                           3
# 1 2024-02-02 09:12:00                            9                           2
# 2 2023-12-03 23:45:00                            5                           2
# 3 2023-06-04 18:47:00                            6                           1
# 4 2023-11-03 09:41:00                            5                           0
